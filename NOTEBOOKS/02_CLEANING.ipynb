# %%
import pandas as pd

df = pd.read_csv("../DATA/RAW/dirty_cafe_sales.csv")

# %% [markdown]
# Les doublons sont supprimés afin d’éviter le double comptage des ventes.

# %%
df = df.drop_duplicates()

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"], errors="coerce")
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors="coerce")

# %% [markdown]
# Les lignes contenant des valeurs manquantes sur des champs critiques ont été supprimées afin de garantir la fiabilité des analyses.

# %%
df = df.dropna(subset=["Transaction Date", "Item", "Quantity", "Price Per Unit"])

# %%
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce")
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors="coerce")
df = df[(df["Quantity"] > 0) & (df["Price Per Unit"] > 0)]

# %%
df["Payment Method"] = df["Payment Method"].fillna("Unknown")

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8581 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    8581 non-null   object
#  1   Item              8581 non-null   object
#  2   Quantity          8581 non-null   float64
#  3   Price Per Unit    8581 non-null   object
#  4   Total Spent       8428 non-null   object
#  5   Payment Method    8581 non-null   object
#  6   Location          5774 non-null   object
#  7   Transaction Date  8581 non-null   object
#  8   Date              8320 non-null   datetime64[ns]
#  9   Unit_Price        8581 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 737.4+ KB
# Transaction ID         0
# Item                   0
# Quantity               0
# Price Per Unit         0
# Total Spent          153
# Payment Method         0
# Location            2807
# Transaction Date       0
# ...
